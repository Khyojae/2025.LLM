# %% [markdown]
# <a href="https://colab.research.google.com/github/Khyojae/2025.LLM/blob/main/openapi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai

# %%
import openai

# %%
from openai import OpenAI
client = OpenAI(api_key=OPENAI_API_KEY)
model = "gpt-3.5-turbo-0125"

# %%
response = client.chat.completions.create(
    model=model,
    messages=messages
)

# 응답 객체 구조가 약간 변경됨: .message 대신 .content 사용
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.

# %%
messages = [{
    "role": "system",
    "content": "You are a helpful assistant."
},{
    "role":"user",
    "content":query
}]
response = client.chat.completions.create(
    model=model,
    messages=messages
)

# 응답 객체 구조가 약간 변경됨: .message 대신 .content 사용
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.

# %%
query = "프랑스의 수도를 알려줘."

messages = [{
    "role": "user",
    "content": query
}]
response = client.chat.completions.create(
    model=model,
    messages=messages
)

# 응답 객체 구조가 약간 변경됨: .message 대신 .content 사용
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다. 파리는 프랑스의 정치, 경제, 문화 중심지이자 인구 밀집 지역입니다. 아름다운 세계적 명소와 유서 깊은 역사를 자랑하는 파리는 매년 많은 관광객들이 방문하는 인기있는 도시입니다.

# %%
messages = [{
    "role": "system",
    "content": "You are a humorous assistant."
},{
    "role":"user",
    "content":query
}]
response = client.chat.completions.create(
    model=model,
    messages=messages
)

# 응답 객체 구조가 약간 변경됨: .message 대신 .content 사용
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리입니다. 그곳에는 에펠탑, 루브르 박물관, 성당 노트르담 등 많은 유명한 명소들이 있죠. 파리에 가보고 싶은가요?

# %%
messages = [{
    "role": "system",
    "content": "You are  a sarcasm assistant."
},{
    "role":"user",
    "content":query
}]
response = client.chat.completions.create(
    model=model,
    messages=messages
)

# 응답 객체 구조가 약간 변경됨: .message 대신 .content 사용
answer = response.choices[0].message.content
print(answer)
# Out:
# 네, 당연히 모뉴피냐겠지요.

# %%
messages = [{
    "role": "system",
    "content": "You are  a pessimistic assistant."
},{
    "role":"user",
    "content":query
}]
response = client.chat.completions.create(
    model=model,
    messages=messages
)

# 응답 객체 구조가 약간 변경됨: .message 대신 .content 사용
answer = response.choices[0].message.content
print(answer)
# Out:
# 당연히 파리죠. 하지만 그것이 왜 중요한지는 잘 모르겠어요.
